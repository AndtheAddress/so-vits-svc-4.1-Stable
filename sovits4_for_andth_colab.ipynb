# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/MyDrive/Colab/so-vits-svc-4.1-Stable')

#!ls
# Out:
# Mounted at /content/gdrive

# %%
#!wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
#     - cryptography==2.8=py38h1ba5d50_0
#     - idna==2.8=py38_1000
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py38_1
#     - pycosat==0.6.3=py38h7b6447c_0
#     - pycparser==2.19=py_0
#     - pyopenssl==19.1.0=py38_0
#     - pysocks==1.7.1=py38_0
#     - python==3.8.1=h0371630_1
#     - readline==7.0=h7b6447c_5
# ...

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   py38       /root/.local/share/jupyter/kernels/py38
#   ir         /usr/local/share/jupyter/kernels/ir
#   python3    /usr/local/share/jupyter/kernels/python3

# %%
# !python -m pip install faiss-gpu
# !python -m pip install librosa
# !python -m pip install pyyaml
# !python -m pip install torch
# !python -m pip install matplotlib
# !python -m pip install torchaudio
# !python -m pip install fairseq
# !python -m pip install pyworld
# !python -m pip install opencv-contrib-python
# !python -m pip install opencv-python
# !python -m pip install tensorboard
#!python -m pip install numpy==1.23.5
#!python -m pip install -U scipy librosa numba
#!python -m pip install numpy==1.23.5

#!python -m pip uninstall parselmouth


#!python -m pip install praat-parselmouth
#!python -m pip install soundfile
#!python -m pip install librosa
# Out:
# ...
#      |████████████████████████████████| 85.5 MB 67 kB/s
# ...
#      |████████████████████████████████| 260 kB 11.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 72.8 MB/s
# ...
#      |████████████████████████████████| 11.1 MB 53.9 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 15 kB/s
# ...
#      |████████████████████████████████| 301 kB 76.7 MB/s
# ...
#      |████████████████████████████████| 3.7 MB 52.6 MB/s
# ...
#      |████████████████████████████████| 64 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 381 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 43.6 MB 1.3 MB/s
# ...
# ERROR: numba 0.58.1 has requirement numpy<1.27,>=1.22, but you'll have numpy 1.20.3 which is incompatible.
# ...
#      |████████████████████████████████| 746 kB 12.0 MB/s
# ...
#      |████████████████████████████████| 797.1 MB 8.3 kB/s
# ...
#      |████████████████████████████████| 823 kB 55.5 MB/s
# ...
#      |████████████████████████████████| 664.8 MB 6.3 kB/s
# ...
#      |████████████████████████████████| 124.2 MB 19 kB/s
# ...

# %%
# !python -m pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 101 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 18.1 MB 733 kB/s
# ...
#      |████████████████████████████████| 17.1 MB 96 kB/s
# ...
#      |████████████████████████████████| 34.5 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 72.3 MB 12 kB/s
# ...
#      |████████████████████████████████| 242 kB 67.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 162 kB 75.5 MB/s
# ...
#      |████████████████████████████████| 10.7 MB 82 kB/s
# ...
#      |████████████████████████████████| 16.0 MB 41.2 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 44.2 MB/s
# ...
#      |████████████████████████████████| 677 kB 32.2 MB/s
# ...
#      |████████████████████████████████| 213 kB 61.0 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 45.8 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.6 MB/s
# ...
#      |████████████████████████████████| 10.0 MB 53.5 MB/s
# ...
#      |████████████████████████████████| 981 kB 64.8 MB/s
# ...

# %%
# !python -m pip install tensorboard
# Out:
# ...
#      |████████████████████████████████| 127 kB 12.7 MB/s
# ...
# ERROR: gradio 4.44.1 has requirement urllib3~=2.0, but you'll have urllib3 1.25.11 which is incompatible.
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
# ...

# %%
# !python -m pip uninstall urllib3
# !python -m pip install urllib3>=2.0
# !python -m pip uninstall pandas
# !python -m pip install pandas>=2.0
# Out:
# Found existing installation: urllib3 1.25.8
# Uninstalling urllib3-1.25.8:
#   Would remove:
#     /usr/local/lib/python3.8/site-packages/urllib3-1.25.8.dist-info/*
#     /usr/local/lib/python3.8/site-packages/urllib3/*
# Proceed (y/n)? y
#   Successfully uninstalled urllib3-1.25.8
# ERROR: requests 2.22.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 2.2.3 which is incompatible.
# Found existing installation: pandas 2.0.3
# Uninstalling pandas-2.0.3:
#   Would remove:
#     /usr/local/lib/python3.8/site-packages/pandas-2.0.3.dist-info/*
#     /usr/local/lib/python3.8/site-packages/pandas/*
# Proceed (y/n)? y
#   Successfully uninstalled pandas-2.0.3

# %%
# !python --version
# !python -m pip list
# Out:
# Python 3.8.1
# Package                  Version
# ------------------------ -------------------
# absl-py                  2.1.0
# aiofiles                 23.2.1
# aiohttp                  3.9.5
# aiosignal                1.3.1
# annotated-types          0.7.0
# antlr4-python3-runtime   4.8
# anyio                    3.5.0
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# asn1crypto               1.3.0
# asttokens                2.0.5
# async-timeout            4.0.3
# attrs                    24.2.0
# audioread                3.0.1
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.12.3
# bitarray                 3.0.0
# bleach                   4.1.0
# blinker                  1.8.2
# boltons                  23.0.0
# cachetools               5.5.0
# certifi                  2024.8.30
# cffi                     1.14.0
# chardet                  3.0.4
# click                    8.1.7
# colorama                 0.4.6
# ...

# %%
# !apt-get install libffi-dev
# !find /usr/lib -name "libffi.so*"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libffi-dev
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 63.7 kB of archives.
# After this operation, 336 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Fetched 63.7 kB in 1s (84.7 kB/s)
# Selecting previously unselected package libffi-dev:amd64.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Processing triggers for man-db (2.10.2-1) ...
# /usr/lib/x86_64-linux-gnu/libffi.so.8.1.0
# /usr/lib/x86_64-linux-gnu/libffi.so.8
# /usr/lib/x86_64-linux-gnu/libffi.so

# %%
# !sudo ln -s /usr/lib/x86_64-linux-gnu/libffi.so.8 /usr/lib/x86_64-linux-gnu/libffi.so.6

# %%
# !python -m pip install --force-reinstall --no-binary :all: cffi
# Out:
# ...
#      |████████████████████████████████| 516 kB 20.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 172 kB 63.2 MB/s
# Skipping wheel build for pycparser, due to binaries being disabled for it.
# ...
#   Created wheel for cffi: filename=cffi-1.17.1-cp38-cp38-linux_x86_64.whl size=433624 sha256=00c98b76912db548168f91a1a7f9258d12600fd4a37edcfd981950ab4b144f10
#   Stored in directory: /root/.cache/pip/wheels/f8/73/f0/643f1772516a6bd314c8e57831b7d5204a45e9fe1b876b6b35
# Successfully built cffi
# ...
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.19
#     Uninstalling pycparser-2.19:
#       Successfully uninstalled pycparser-2.19
#     Running setup.py install for pycparser ... done
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.14.0
#     Uninstalling cffi-1.14.0:
#       Successfully uninstalled cffi-1.14.0
# ...

# %%
# !python resample.py
# Out:
# CPU count: 2
# ./dataset_raw/yylz
# resampling: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:51

# %%
# !python preprocess_flist_config.py --speech_encoder vec768l12 --vol_aug
# Out:
#   0% 0/1 [00:00<?, ?it/s]2024-11-30 12:15:48.071 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_67.wav
# 2024-11-30 12:15:48.075 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_22.wav
# 2024-11-30 12:15:48.078 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_45.wav
# 2024-11-30 12:15:48.081 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_37.wav
# 2024-11-30 12:15:48.085 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_42.wav
# 2024-11-30 12:15:48.089 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_73.wav
# 2024-11-30 12:15:48.121 | WARNING  | __main__:<module>:59 - Detected non-ASCII file name: ./dataset/44k/yylz/1_hs_(Vocals)_36.wav
# ...

# %%
# !python preprocess_hubert_f0.py --f0_predictor dio
# Out:
# vec768l12
# 2024-11-30 12:19:05.550 | INFO     | __main__:<module>:152 - Using device: cpu
# 2024-11-30 12:19:05.550 | INFO     | __main__:<module>:153 - Using SpeechEncoder: vec768l12
# 2024-11-30 12:19:05.550 | INFO     | __main__:<module>:154 - Using extractor: dio
# 2024-11-30 12:19:05.550 | INFO     | __main__:<module>:155 - Using diff Mode: False
#   0% 0/1 [00:00<?, ?it/s]2024-11-30 12:19:10.407 | INFO     | __mp_main__:process_batch:107 - Loading speech encoder for content...
# 2024-11-30 12:19:10.408 | INFO     | __mp_main__:process_batch:113 - Rank 1 uses device cpu
# load model(s) from pretrain/checkpoint_best_legacy_500.pt
# ...

# %%
# !python train.py -c configs/config.json -m 44k
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !python inference_main.py -m "logs/44k/G_8000.pth" -c "configs/config.json" -n "aiv2.wav" -t 0 -s "yylz"
# Out:
# /usr/local/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...
